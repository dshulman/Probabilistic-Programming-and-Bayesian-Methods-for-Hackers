# %%
import matplotlib
matplotlib.__file__
# Out:
# '/home/codespace/.local/lib/python3.10/site-packages/matplotlib/__init__.py'

# %%
# %pip list
# Out:
# Package                   Version
# ------------------------- ------------
# anyio                     4.0.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.2.3
# arviz                     0.16.1
# asttokens                 2.4.0
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.12.1
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    6.0.0
# cachetools                5.3.1
# certifi                   2023.7.22
# cffi                      1.16.0
# charset-normalizer        3.2.0
# cloudpickle               2.2.1
# cmake                     3.27.5
# colorama                  0.4.6
# comm                      0.1.4
# cons                      0.4.2
# contourpy                 1.1.1
# cryptography              41.0.4
# cycler                    0.12.0
# debugpy                   1.8.0
# decorator                 5.1.1
# ...
